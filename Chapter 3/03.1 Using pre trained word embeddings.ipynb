# %% [markdown]
# ## Text Similarity using Word Embeddings
#
# In this notebook we're going to play around with pre build word embeddings and do some fun calculations:

# %%
# %matplotlib inline

import os
from keras.utils import get_file
import gensim
import subprocess
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
figsize(10, 10)

from sklearn.manifold import TSNE
import json
from collections import Counter
from itertools import chain

# %% [markdown]
# We'll start by downloading a pretrained model from Google News. We're using `zcat` to unzip the file, so you need to make sure you have that installed or replace it by something else.

# %%
MODEL = 'GoogleNews-vectors-negative300.bin'
path = get_file(MODEL + '.gz', 'https://s3.amazonaws.com/dl4j-distribution/%s.gz' % MODEL)
if not os.path.isdir('../data/generated'):
    os.mkdir('../data/generated')

unzipped = os.path.join('../data/generated', MODEL)
if not os.path.isfile(unzipped):
    with open(unzipped, 'wb') as fout:
        zcat = subprocess.Popen(['zcat'],
                          stdin=open(path),
                          stdout=fout
                         )
        zcat.wait()
# Out:
# Downloading data from https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# 1647050752/1647046227 [==============================] - 427s 0us/step

# %%
model = gensim.models.KeyedVectors.load_word2vec_format(unzipped, binary=True)

# %% [markdown]
# Let's take this model for a spin by looking at what things are most similar to espresso. As expected, coffee like items show up:

# %%
model.most_similar(positive=['espresso'])
# Out:
# [('cappuccino', 0.6888186931610107),
#  ('mocha', 0.6686208844184875),
#  ('coffee', 0.6616826057434082),
#  ('latte', 0.6536753177642822),
#  ('caramel_macchiato', 0.6491268873214722),
#  ('ristretto', 0.6485545635223389),
#  ('espressos', 0.6438628435134888),
#  ('macchiato', 0.6428250074386597),
#  ('chai_latte', 0.6308028697967529),
#  ('espresso_cappuccino', 0.6280542612075806)]

# %% [markdown]
# Now for the famous equation, what is like woman if king is like man? We create a quick method to these calculations here:

# %%
def A_is_to_B_as_C_is_to(a, b, c, topn=1):
    a, b, c = map(lambda x:x if type(x) == list else [x], (a, b, c))
    res = model.most_similar(positive=b + c, negative=a, topn=topn)
    if len(res):
        if topn == 1:
            return res[0][0]
        return [x[0] for x in res]
    return None

A_is_to_B_as_C_is_to('man', 'woman', 'king')
# Out:
# 'queen'

# %% [markdown]
# We can use this equation to acurately predict the capitals of countries by looking at what has the same relationship as Berlin has to Germany for selected countries:

# %%
for country in 'Italy', 'France', 'India', 'China':
    print('%s is the capital of %s' % 
          (A_is_to_B_as_C_is_to('Germany', 'Berlin', country), country))
# Out:
# Rome is the capital of Italy
# Paris is the capital of France
# Delhi is the capital of India
# Beijing is the capital of China

# %% [markdown]
# Or we can do the same for important products for given companies. Here we seed the products equation with two products, the iPhone for Apple and Starbucks_coffee for Starbucks. Note that numbers are replaced by # in the embedding model:

# %%
for company in 'Google', 'IBM', 'Boeing', 'Microsoft', 'Samsung':
    products = A_is_to_B_as_C_is_to(
        ['Starbucks', 'Apple'], 
        ['Starbucks_coffee', 'iPhone'], 
        company, topn=3)
    print('%s -> %s' % 
          (company, ', '.join(products)))
# Out:
# Google -> personalized_homepage, app, Gmail
# IBM -> DB2, WebSphere_Portal, Tamino_XML_Server
# Boeing -> Dreamliner, airframe, aircraft
# Microsoft -> Windows_Mobile, SyncMate, Windows
# Samsung -> MM_A###, handset, Samsung_SCH_B###

# %% [markdown]
# Let's do some clustering by picking three categories of items, drinks, countries and sports:

# %%
beverages = ['espresso', 'beer', 'vodka', 'wine', 'cola', 'tea']
countries = ['Italy', 'Germany', 'Russia', 'France', 'USA', 'India']
sports = ['soccer', 'handball', 'hockey', 'cycling', 'basketball', 'cricket']

items = beverages + countries + sports
len(items)
# Out:
# 18

# %% [markdown]
# And looking up their vectors:

# %%
item_vectors = [(item, model[item]) 
                    for item in items
                    if item in model]
len(item_vectors)
# Out:
# 18

# %% [markdown]
# Now use TSNE for clustering:

# %%
vectors = np.asarray([x[1] for x in item_vectors])
lengths = np.linalg.norm(vectors, axis=1)
norm_vectors = (vectors.T / lengths).T

tsne = TSNE(n_components=2, perplexity=10, verbose=2).fit_transform(norm_vectors)
# Out:
# [t-SNE] Computing 17 nearest neighbors...
# [t-SNE] Indexed 18 samples in 0.000s...
# [t-SNE] Computed neighbors for 18 samples in 0.020s...
# [t-SNE] Computed conditional probabilities for sample 18 / 18
# [t-SNE] Mean sigma: 0.581543
# [t-SNE] Computed conditional probabilities in 0.001s
# [t-SNE] Iteration 50: error = 55.3753166, gradient norm = 0.0638135 (50 iterations in 0.010s)
# [t-SNE] Iteration 100: error = 53.1883888, gradient norm = 0.0780682 (50 iterations in 0.009s)
# [t-SNE] Iteration 150: error = 55.4353867, gradient norm = 0.1351119 (50 iterations in 0.010s)
# [t-SNE] Iteration 200: error = 55.2528725, gradient norm = 0.0635160 (50 iterations in 0.008s)
# [t-SNE] Iteration 250: error = 58.1581192, gradient norm = 0.0902959 (50 iterations in 0.007s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.158119
# [t-SNE] Iteration 300: error = 0.8665959, gradient norm = 0.0008721 (50 iterations in 0.006s)
# [t-SNE] Iteration 350: error = 0.6858785, gradient norm = 0.0005081 (50 iterations in 0.006s)
# [t-SNE] Iteration 400: error = 0.5726339, gradient norm = 0.0003412 (50 iterations in 0.006s)
# [t-SNE] Iteration 450: error = 0.5236226, gradient norm = 0.0002605 (50 iterations in 0.006s)
# [t-SNE] Iteration 500: error = 0.4082002, gradient norm = 0.0004802 (50 iterations in 0.007s)
# [t-SNE] Iteration 550: error = 0.2678360, gradient norm = 0.0003892 (50 iterations in 0.006s)
# [t-SNE] Iteration 600: error = 0.1663676, gradient norm = 0.0003104 (50 iterations in 0.007s)
# [t-SNE] Iteration 650: error = 0.1389097, gradient norm = 0.0001319 (50 iterations in 0.016s)
# [t-SNE] Iteration 700: error = 0.1253928, gradient norm = 0.0000948 (50 iterations in 0.006s)
# [t-SNE] Iteration 750: error = 0.1110337, gradient norm = 0.0000802 (50 iterations in 0.006s)
# [t-SNE] Iteration 800: error = 0.1022276, gradient norm = 0.0000634 (50 iterations in 0.006s)
# [t-SNE] Iteration 850: error = 0.0979159, gradient norm = 0.0000353 (50 iterations in 0.006s)
# [t-SNE] Iteration 900: error = 0.0959697, gradient norm = 0.0000264 (50 iterations in 0.006s)
# [t-SNE] Iteration 950: error = 0.0948182, gradient norm = 0.0000242 (50 iterations in 0.006s)
# [t-SNE] Iteration 1000: error = 0.0937781, gradient norm = 0.0000206 (50 iterations in 0.006s)
# [t-SNE] KL divergence after 1000 iterations: 0.093778

# %% [markdown]
# And matplotlib to show the results:

# %%
x=tsne[:,0]
y=tsne[:,1]

fig, ax = plt.subplots()
ax.scatter(x, y)

for item, x1, y1 in zip(item_vectors, x, y):
    ax.annotate(item[0], (x1, y1), size=14)

plt.show()

# %% [markdown]
# As you can see, the countries, sports and drinks all form their own little clusters, with arguably cricket and India attracting each other and maybe less clear, wine and France and Italy and espresso.
